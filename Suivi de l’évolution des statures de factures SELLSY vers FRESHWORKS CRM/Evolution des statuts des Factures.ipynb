# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Récuperation de la liste des factures sellsy (anciennes et futures)</span>

# %%
from babel.numbers import format_currency
import json
import requests
from requests_oauthlib import OAuth1
from oauthlib.oauth1 import SIGNATURE_PLAINTEXT, SIGNATURE_TYPE_BODY
import pandas as pd


def sellsyFacturation():
    consumer_token = ''
    consumer_secret = ''
    user_token = ''
    user_secret = ''
    url = 'https://apifeed.sellsy.com/0/'
    
    auth = OAuth1(
        consumer_token,
        consumer_secret,
        user_token,
        user_secret,
        signature_method=SIGNATURE_PLAINTEXT,
        signature_type=SIGNATURE_TYPE_BODY,
    )

    payload = {'method': 'DocRows.getList', 'params': {'doctype': 'invoice', 'pagination': {'nbperpage': 2000}}}
    
    response = requests.post(url, data={
        'request': 1,
        'io_mode': 'json',
        'do_in': json.dumps(payload)
    }, auth=auth, headers={'content-type': 'application/json'})
    
    data = response.json()
    
    client = data['response']['result']
    
    liste_ident = []
    liste_doc_thirdname = []
    liste_name = []
    liste_date = []
    liste_doc_totalAmountTaxesFree = []
    liste_email = []
    liste_statut = []
    liste_tel = []
    
    for i in client:
        numero = client[i].get('id', None)
        liste_ident.append(numero)

        doc_thirdname = client[i].get('doc_thirdname', None)
        liste_doc_thirdname.append(doc_thirdname)

        tel = client[i]["thirdDetails"].get('tel', None)
        liste_tel.append(tel)
        
        doc_name = client[i].get('name', None)
        liste_name.append(doc_name)

        doc_date = client[i].get('formatted_doc_created', None)
        liste_date.append(doc_date)

        doc_totalAmountTaxesFree = client[i].get('doc_totalAmountTaxesFree', None)
        if doc_totalAmountTaxesFree is not None:
            montant_formate = format_currency(float(doc_totalAmountTaxesFree), 'EUR', locale='fr_FR')
        else:
            montant_formate = None
        liste_doc_totalAmountTaxesFree.append(montant_formate)

        email = client[i]['thirdDetails'].get('email', None)
        liste_email.append(email)

        statut = client[i]['stepDoc'].get('label', None)
        liste_statut.append(statut)
    df_sellsy = pd.DataFrame(list(zip(
        liste_ident, liste_doc_thirdname,liste_date, liste_tel, liste_email,
        liste_doc_totalAmountTaxesFree, liste_statut, liste_name,
    )), 
    columns=[
        "ID", "Nom complet", "Date", "Mobile", "Email",
        "Montant", "Statut", "Name",
    ])

    return df_sellsy

# %%
currencys=sellsyFacturation()
currencys.to_csv("actuelle.csv", index=False)
currencys

# %%
currencyt = currencys.groupby(["Nom complet","Mobile","Email"],as_index=False)[["Date","Statut","Montant","Name"]].agg('/'.join)
print("c'est bon")
currencyt.to_csv("az.csv", index=False)
currencyt

# %%
import pandas as pd

currency = pd.read_csv("az.csv", encoding='utf-8')

print(currency.head())
currency

# %%
def calculer_somme_montants(montant):
    try:
        montant = montant.replace('€', '').replace('\u202f', '').replace(',', '.').strip()

        montants = [float(x.strip()) for x in montant.split('/')]
        return sum(montants)
    except:
        return 0.0

currency["Montant Sommé"] = currency["Montant"].apply(calculer_somme_montants)

print(currency[["Montant", "Montant Sommé"]].head())

hg = currency.groupby(
    ["Date","Mobile", 'Email', "Name", "Statut"],
    as_index=False
)[["Montant Sommé"]].sum()

try:
    hg.to_csv("az.csv", index=False)
    print("fichier az.csv enregistré")
except Exception as e:
    print(f"Erreur : {e}")

print(currency.head())
print(hg.head())
currency.to_csv("azfsdt.csv", index=False)
currency

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Filtrage de la facture la plus recente</span>

# %%
import pandas as pd
from datetime import datetime

df = pd.read_csv('azfsdt.csv')

def get_statut_recent(row):
    raw_dates = str(row['Date']).split('/')
    raw_statuts = str(row['Statut']).split('/')

    parsed_dates = []
    for d in raw_dates:
        try:
            parsed_dates.append(datetime.strptime(d.strip(), "%d/%m/%Y"))
        except:
            parsed_dates.append(None)

    clean = [(d, s) for d, s in zip(parsed_dates, raw_statuts) if d is not None]

    if not clean:
        return raw_statuts[-1] if raw_statuts else None
    return max(clean, key=lambda x: x[0])[1]

df['Statut récent'] = df.apply(get_statut_recent, axis=1)

df[['Nom complet', 'Date', 'Statut', 'Statut récent']]
df.to_csv("azfsdtord.csv", index=False)
df

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Liste des contacts - Fresh</span>

# %%
import requests
import pandas as pd
import time

API_KEY_FRESHWORK = ''
DOMAIN_FRESHWORK = ''
BASE_URL = f'https://{DOMAIN_FRESHWORK}.myfreshworks.com/crm/sales/'

def get_existing_contacts(api_key, domain):
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Token token={api_key}'
    }
    all_contacts = {}
    page = 1
    last_contact_id = None

    while True:
        params = {'per_page': 100, 'page': page}
        if last_contact_id:
            params['last_contact_id'] = last_contact_id
        url = f"{BASE_URL}api/contacts/view/31004512042?per_page=100&sort=created_at"

        response = requests.get(url, headers=headers, params=params)
        if not response.ok:
            print(f"Erreur lors de la récupération des données : {response.status_code}")
            return

        response_data = response.json()
        if 'contacts' not in response_data:
            print("Erreur dans la structure de la réponse JSON")
            break

        contacts_data = response_data['contacts']
        if not contacts_data:
            break

        for contact in contacts_data:
            custom_field = contact.get("custom_field", {})
            bitrix_id = custom_field.get('cf_id_bitrix')
            if bitrix_id:
                all_contacts[bitrix_id] = contact

        last_contact_id = contacts_data[-1]['id']
        page += 1
        time.sleep(1)

    print(f"Contacts récupérés avec succès : {len(all_contacts)}")
    return all_contacts

def main():
    existing_contacts = get_existing_contacts(API_KEY_FRESHWORK, DOMAIN_FRESHWORK)
    data = {
        "internal_id": [],
        "first_name": [],
        "last_name": [],
        "email": [],
        "work_number": [],
        "mobile_number": [],
        "phone_number": [],  
        "cf_id_bitrix": [], 
        "updated_at": []
    }

    for contact in existing_contacts.values():
        data["internal_id"].append(contact.get("id", ""))
        data["first_name"].append(contact.get("first_name", ""))
        data["last_name"].append(contact.get("last_name", ""))
        data["email"].append(contact.get("email", ""))
        data["work_number"].append(contact.get("work_number", ""))
        data["mobile_number"].append(contact.get("mobile_number", ""))

        custom_field = contact.get("custom_field", {})
        data["phone_number"].append(custom_field.get("cf_nom_du_prospect", ""))
        data["cf_id_bitrix"].append(custom_field.get("cf_id_bitrix", ""))

        updated_at = contact.get("updated_at", "")
        if updated_at:
            updated_at = updated_at.split("T")[0]
        data["updated_at"].append(updated_at)

    df_combined = pd.DataFrame(data)
    df_combined["updated_at"] = pd.to_datetime(df_combined["updated_at"])
    df_combined["month_year"] = df_combined["updated_at"].dt.to_period('M')
    df_combined = df_combined.sort_values(by="month_year", ascending=False)
    df_combined = df_combined.drop(columns=["month_year"])
    df_combined = df_combined.reset_index(drop=True)
    
    df_combined.to_csv('contacts_rs.csv', index=False, encoding='utf-8')
    
    return df_combined

if __name__ == '__main__':
    contacts_df = main()
    print(contacts_df)

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Récuperation de la liste des affaires-Freshworks</span>

# %%
import requests
import pandas as pd
import time

API_KEY = ""
DOMAIN = ""
HEADERS = {
    "Content-Type": "application/json",
    "Authorization": f"Token token={API_KEY}"
}

def fetch_data(endpoint):
    url = f"https://{DOMAIN}.myfreshworks.com/crm/sales/api/selector/{endpoint}"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return {item["id"]: item["name"] for item in response.json().get(endpoint, [])}
    return {}

def get_pipelines():
    url = f"https://{DOMAIN}.myfreshworks.com/crm/sales/api/selector/deal_pipelines"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return {p["id"]: p["name"] for p in response.json().get("deal_pipelines", [])}
    return {}

def get_pipeline_stages(pipeline_id):
    url = f"https://{DOMAIN}.myfreshworks.com/crm/sales/api/selector/deal_pipelines/{pipeline_id}/deal_stages"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return {s["id"]: s["name"] for s in response.json().get("deal_stages", [])}
    return {}

def get_view_id_by_name(view_name):
    url = f"https://{DOMAIN}.myfreshworks.com/crm/sales/api/deals/filters"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        filters = response.json().get("filters", [])
        for f in filters:
            if f["name"].lower() == view_name.lower():
                return f["id"]
    return None

def get_deals(view_id):
    all_deals = []
    page = 1
    while True:
        url = f"https://{DOMAIN}.myfreshworks.com/crm/sales/api/deals/view/{view_id}"
        params = {"per_page": 100, "page": page}
        response = requests.get(url, headers=HEADERS, params=params)
        if response.status_code != 200:
            return []
        deals = response.json().get("deals", [])
        if not deals:
            break
        all_deals.extend(deals)
        print(f"{len(all_deals)} deals récupérés...")
        page += 1
        time.sleep(1)
    return all_deals

def save_deals_to_csv(deals, deal_stages, lifecycle_stages, owners, pipelines):
    data = {
        "deal_id": [], "name": [], "amount": [], "pipeline": [], "stage": [],
        "lifecycle_stage": [], "owner": [], "created_at": [], "updated_at": []
    }
    for deal in deals:
        pipeline_name = pipelines.get(deal.get("deal_pipeline_id", ""), "Inconnu")
        stage_name = deal_stages.get(deal.get("deal_stage_id", ""), "Inconnu")
        lifecycle_name = lifecycle_stages.get(deal.get("lifecycle_stage_id", ""), "Inconnu")
        owner_name = owners.get(deal.get("owner_id", ""), "Inconnu")

        data["deal_id"].append(deal.get("id", ""))
        data["name"].append(deal.get("name", ""))
        data["amount"].append(deal.get("amount", ""))
        data["pipeline"].append(pipeline_name)
        data["stage"].append(stage_name)
        data["lifecycle_stage"].append(lifecycle_name)
        data["owner"].append(owner_name)
        data["created_at"].append(deal.get("created_at", "").split("T")[0] if deal.get("created_at") else "")
        data["updated_at"].append(deal.get("updated_at", "").split("T")[0] if deal.get("updated_at") else "")
    
    df = pd.DataFrame(data)
    df.to_csv("deals.csv", index=False, encoding="utf-8")
    print(f"{len(df)} deals enregistrés dans 'deals.csv'")

def main():
    print("Pause de 10 min avant la récupération des données pour eviter erreur 429...")
    time.sleep(600)

    view_name = "Open Deals" 
    view_id = get_view_id_by_name(view_name)
    
    if view_id:
        pipelines = get_pipelines()
        deal_stages = {}
        for pipeline_id in pipelines.keys():
            deal_stages.update(get_pipeline_stages(pipeline_id))
        lifecycle_stages = fetch_data("lifecycle_stages")
        owners = fetch_data("owners")
        deals = get_deals(view_id)
        save_deals_to_csv(deals, deal_stages, lifecycle_stages, owners, pipelines)
    else:
        print(f"Filtre '{view_name}' non trouvé.")

if __name__ == "__main__":
    main()

# %%
sellsy = 'deals.csv'
sellsy = pd.read_csv(sellsy)
sellsy

# %% [markdown]
# <span style="color: white; font-weight: bold; font-size: 50px;"> Detection des statut SI</span>

# %%
import pandas as pd

df = pd.read_csv('azfsdtord.csv')

filtré = df[df['Name'].str.contains('seance initial|seg|1ère séance|SI seance', case=False, na=False)]

filtré.to_csv("azfsdtordzer.csv", index=False)
filtré

# %%
import pandas as pd

df = pd.read_csv('azfsdtordzer.csv')

filtré = df[df['Statut récent'].str.contains('payée', case=False, na=False)]

filtré.to_csv("azfsdtordzersd.csv", index=False)
filtré

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Changement De Statut en "Premier bilan effectué" si SEG ou SI est payé sur sellsy</span>

# %%
import csv
import requests
import time
from datetime import datetime

API_KEY_FRESHWORK = ''
DOMAIN_FRESHWORK = ''
BASE_URL = f'https://{DOMAIN_FRESHWORK}.myfreshworks.com/crm/sales/'

HEADERS = {
    'Content-Type': 'application/json',
    'Authorization': f'Token token={API_KEY_FRESHWORK}'
}

DEFAULT_DEAL_STAGE_ID = 31000543861
LOG_FILE = "log_traitement.txt"

def log(message):
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open(LOG_FILE, "a", encoding="utf-8") as log_file:
        log_file.write(f"[{timestamp}] {message}\n")
    print(message)

def get_existing_contacts():
    log("Début récupération des contacts existants...")
    all_contacts = {}
    page = 1
    while True:
        url = f"{BASE_URL}api/contacts/view/31004512042?sort=created_at&per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            log(f"Erreur contacts: {response.text}")
            return {}
        contacts_data = response.json().get("contacts", [])
        if not contacts_data:
            break
        for contact in contacts_data:
            email = contact.get("email")
            if email:
                all_contacts[email.strip().lower()] = contact["id"]
        page += 1
        time.sleep(1)
    log(f"{len(all_contacts)} contacts récupérés.")
    return all_contacts

def get_existing_deal(contact_id):
    url = f"{BASE_URL}api/contacts/{contact_id}/deals"
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        log(f"Erreur récupération des affaires pour contact {contact_id}")
        return None
    deals = response.json().get("deals", [])
    for deal in deals:
        try:
            amount = float(deal.get("amount", 0) or 0)
        except:
            amount = 0
        if amount > 0:
            return deal
    return None

def update_deal_stage(deal_id, new_stage_id=DEFAULT_DEAL_STAGE_ID):
    url = f"{BASE_URL}api/deals/{deal_id}"
    payload = {
        "deal": {
            "deal_stage_id": new_stage_id
        }
    }
    response = requests.put(url, headers=HEADERS, json=payload)
    if response.status_code == 200:
        log(f"Affaire {deal_id} mise à jour vers 'Premier bilan effectué'")
    else:
        log(f"Erreur mise à jour affaire {deal_id}: {response.text}")

def main():
    log("Pause 1/2 : 1 heure avant récupération des contacts...")
    time.sleep(3600)

    existing_contacts = get_existing_contacts()

    with open('azfsdtordzersd.csv', 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        bitrix_contacts = list(reader)

    log("Pause 2/2 : 1 heure avant mise à jour des affaires...")
    time.sleep(3600)

    for contact in bitrix_contacts:
        email = contact.get('Email', '').strip().lower()
        if not email:
            continue
        if email in existing_contacts:
            contact_id = existing_contacts[email]
            deal = get_existing_deal(contact_id)
            if deal:
                update_deal_stage(deal['id'])
        time.sleep(1)

    log("Traitement terminé.")

if __name__ == "__main__":
    main()
# Out:
# Pause 1/2 : 1 heure avant récupération des contacts...
# Début récupération des contacts existants...
# 38730 contacts récupérés.
# Pause 2/2 : 1 heure avant mise à jour des affaires...
# Affaire 31003593093 mise à jour vers 'Premier bilan effectué'
# Affaire 31003144848 mise à jour vers 'Premier bilan effectué'
# Affaire 31003601984 mise à jour vers 'Premier bilan effectué'
# Affaire 31003593084 mise à jour vers 'Premier bilan effectué'
# Affaire 31005928505 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031391 mise à jour vers 'Premier bilan effectué'
# Affaire 31003516195 mise à jour vers 'Premier bilan effectué'
# Affaire 31003581241 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031198 mise à jour vers 'Premier bilan effectué'
# Affaire 31003618186 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030358 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031332 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031492 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030419 mise à jour vers 'Premier bilan effectué'
# Affaire 31005949462 mise à jour vers 'Premier bilan effectué'
# Affaire 31004008644 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032209 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031214 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030363 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030999 mise à jour vers 'Premier bilan effectué'
# Affaire 31003955653 mise à jour vers 'Premier bilan effectué'
# Affaire 31004070029 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030989 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031371 mise à jour vers 'Premier bilan effectué'
# Affaire 31006636432 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032056 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031213 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030336 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030987 mise à jour vers 'Premier bilan effectué'
# Affaire 31003568318 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031015 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032287 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030352 mise à jour vers 'Premier bilan effectué'
# Affaire 31004031915 mise à jour vers 'Premier bilan effectué'
# Affaire 31003956162 mise à jour vers 'Premier bilan effectué'
# Affaire 31003144856 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032053 mise à jour vers 'Premier bilan effectué'
# Affaire 31003046175 mise à jour vers 'Premier bilan effectué'
# Affaire 31003494004 mise à jour vers 'Premier bilan effectué'
# Affaire 31003514571 mise à jour vers 'Premier bilan effectué'
# Affaire 31003883684 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030933 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030414 mise à jour vers 'Premier bilan effectué'
# Affaire 31005206086 mise à jour vers 'Premier bilan effectué'
# Affaire 31004056265 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030899 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030988 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030926 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030445 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030486 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030927 mise à jour vers 'Premier bilan effectué'
# Affaire 31003965978 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031212 mise à jour vers 'Premier bilan effectué'
# Affaire 31006076738 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030426 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031363 mise à jour vers 'Premier bilan effectué'
# Affaire 31003135870 mise à jour vers 'Premier bilan effectué'
# Affaire 31003479157 mise à jour vers 'Premier bilan effectué'
# Affaire 31003148104 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031307 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031177 mise à jour vers 'Premier bilan effectué'
# Affaire 31004009007 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030346 mise à jour vers 'Premier bilan effectué'
# Affaire 31003518082 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030364 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030357 mise à jour vers 'Premier bilan effectué'
# Affaire 31003618535 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031020 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032088 mise à jour vers 'Premier bilan effectué'
# Affaire 31004060024 mise à jour vers 'Premier bilan effectué'
# Affaire 31006030186 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031479 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031466 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030211 mise à jour vers 'Premier bilan effectué'
# Affaire 31004026752 mise à jour vers 'Premier bilan effectué'
# Affaire 31003715022 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030366 mise à jour vers 'Premier bilan effectué'
# Affaire 31005926222 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030897 mise à jour vers 'Premier bilan effectué'
# Affaire 31004026915 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031475 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031662 mise à jour vers 'Premier bilan effectué'
# Affaire 31005213369 mise à jour vers 'Premier bilan effectué'
# Affaire 31005855318 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031301 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031352 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030371 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031001 mise à jour vers 'Premier bilan effectué'
# Affaire 31003606632 mise à jour vers 'Premier bilan effectué'
# Affaire 31003507788 mise à jour vers 'Premier bilan effectué'
# Affaire 31004300722 mise à jour vers 'Premier bilan effectué'
# Affaire 31003640735 mise à jour vers 'Premier bilan effectué'
# Affaire 31003563775 mise à jour vers 'Premier bilan effectué'
# Affaire 31003483501 mise à jour vers 'Premier bilan effectué'
# Affaire 31004030719 mise à jour vers 'Premier bilan effectué'
# Affaire 31003699678 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030919 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030989 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030485 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030344 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031203 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031666 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030501 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030367 mise à jour vers 'Premier bilan effectué'
# Affaire 31005973999 mise à jour vers 'Premier bilan effectué'
# Affaire 31004008382 mise à jour vers 'Premier bilan effectué'
# Affaire 31003046166 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032241 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031423 mise à jour vers 'Premier bilan effectué'
# Affaire 31003058267 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030917 mise à jour vers 'Premier bilan effectué'
# Affaire 31003564159 mise à jour vers 'Premier bilan effectué'
# Affaire 31003629436 mise à jour vers 'Premier bilan effectué'
# Affaire 31005974028 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031311 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032082 mise à jour vers 'Premier bilan effectué'
# Affaire 31006030036 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030915 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030343 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030992 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030218 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031285 mise à jour vers 'Premier bilan effectué'
# Affaire 31006076610 mise à jour vers 'Premier bilan effectué'
# Affaire 31003877189 mise à jour vers 'Premier bilan effectué'
# Affaire 31006959083 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030913 mise à jour vers 'Premier bilan effectué'
# Affaire 31006016288 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030427 mise à jour vers 'Premier bilan effectué'
# Affaire 31005954677 mise à jour vers 'Premier bilan effectué'
# Affaire 31003615380 mise à jour vers 'Premier bilan effectué'
# Affaire 31003660238 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032214 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031333 mise à jour vers 'Premier bilan effectué'
# Affaire 31006081594 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032218 mise à jour vers 'Premier bilan effectué'
# Affaire 31003886021 mise à jour vers 'Premier bilan effectué'
# Affaire 31004060203 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030331 mise à jour vers 'Premier bilan effectué'
# Affaire 31003627990 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031471 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031019 mise à jour vers 'Premier bilan effectué'
# Affaire 31003046122 mise à jour vers 'Premier bilan effectué'
# Affaire 31003606374 mise à jour vers 'Premier bilan effectué'
# Affaire 31004034524 mise à jour vers 'Premier bilan effectué'
# Affaire 31006030080 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030928 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031180 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030990 mise à jour vers 'Premier bilan effectué'
# Affaire 31006032883 mise à jour vers 'Premier bilan effectué'
# Affaire 31003509365 mise à jour vers 'Premier bilan effectué'
# Affaire 31005949540 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032253 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030433 mise à jour vers 'Premier bilan effectué'
# Affaire 31003617102 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031220 mise à jour vers 'Premier bilan effectué'
# Affaire 31005855308 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032255 mise à jour vers 'Premier bilan effectué'
# Affaire 31004007280 mise à jour vers 'Premier bilan effectué'
# Affaire 31005954698 mise à jour vers 'Premier bilan effectué'
# Affaire 31005973875 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031003 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031368 mise à jour vers 'Premier bilan effectué'
# Affaire 31005949428 mise à jour vers 'Premier bilan effectué'
# Affaire 31005973965 mise à jour vers 'Premier bilan effectué'
# Affaire 31003135835 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031355 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031308 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030993 mise à jour vers 'Premier bilan effectué'
# Affaire 31004020472 mise à jour vers 'Premier bilan effectué'
# Affaire 31004019943 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030444 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031382 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030903 mise à jour vers 'Premier bilan effectué'
# Affaire 31006025739 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030339 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032165 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031328 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031000 mise à jour vers 'Premier bilan effectué'
# Affaire 31003513314 mise à jour vers 'Premier bilan effectué'
# Affaire 31003660043 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030916 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030929 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030981 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030902 mise à jour vers 'Premier bilan effectué'
# Affaire 31004071275 mise à jour vers 'Premier bilan effectué'
# Affaire 31005855305 mise à jour vers 'Premier bilan effectué'
# Affaire 31005209990 mise à jour vers 'Premier bilan effectué'
# Affaire 31004034397 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032184 mise à jour vers 'Premier bilan effectué'
# Affaire 31005971496 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031188 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031239 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031473 mise à jour vers 'Premier bilan effectué'
# Affaire 31004009038 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030921 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031024 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030922 mise à jour vers 'Premier bilan effectué'
# Affaire 31003507285 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031341 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031174 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031398 mise à jour vers 'Premier bilan effectué'
# Affaire 31005735062 mise à jour vers 'Premier bilan effectué'
# Affaire 31003032213 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031006 mise à jour vers 'Premier bilan effectué'
# Affaire 31004056571 mise à jour vers 'Premier bilan effectué'
# Affaire 31003533306 mise à jour vers 'Premier bilan effectué'
# Affaire 31003144859 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030411 mise à jour vers 'Premier bilan effectué'
# Affaire 31003834150 mise à jour vers 'Premier bilan effectué'
# Affaire 31003628412 mise à jour vers 'Premier bilan effectué'
# Affaire 31005973940 mise à jour vers 'Premier bilan effectué'
# Affaire 31003566114 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031367 mise à jour vers 'Premier bilan effectué'
# Affaire 31006062326 mise à jour vers 'Premier bilan effectué'
# Affaire 31003517556 mise à jour vers 'Premier bilan effectué'
# Affaire 31003031326 mise à jour vers 'Premier bilan effectué'
# Affaire 31003484294 mise à jour vers 'Premier bilan effectué'
# Affaire 31005928459 mise à jour vers 'Premier bilan effectué'
# Affaire 31003030893 mise à jour vers 'Premier bilan effectué'
# Traitement terminé.

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Detection des statut Retard / Impayé</span>

# %%
import pandas as pd

df = pd.read_csv('azfsdtord.csv')

filtré = df[df['Statut récent'].str.contains('Retard|Impayé', case=False, na=False)]

filtré.to_csv("azfsdtordzer_impayer.csv", index=False)
filtré

# %%
import csv
import requests
import time

API_KEY_FRESHWORK = ''
DOMAIN_FRESHWORK = ''
BASE_URL = f'https://{DOMAIN_FRESHWORK}.myfreshworks.com/crm/sales/'

HEADERS = {
    'Content-Type': 'application/json',
    'Authorization': f'Token token={API_KEY_FRESHWORK}'
}

DEFAULT_DEAL_STAGE_ID = 31000543867

def get_existing_contacts():
    print("\nRécupération des contacts existants (email)...")
    all_contacts = {}
    page = 1
    while True:
        url = f"{BASE_URL}api/contacts/view/31004512042?sort=created_at&per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Erreur contacts: {response.text}")
            return {}
        contacts_data = response.json().get("contacts", [])
        if not contacts_data:
            break
        for contact in contacts_data:
            email = contact.get("email")
            if email:
                all_contacts[email.strip().lower()] = contact["id"]
        page += 1
        time.sleep(1)
    print(f"{len(all_contacts)} contacts récupérés.")
    return all_contacts

def get_existing_deal(contact_id):
    url = f"{BASE_URL}api/contacts/{contact_id}/deals"
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Erreur récupération des affaires pour contact {contact_id}")
        return None
    deals = response.json().get("deals", [])
    for deal in deals:
        try:
            amount = float(deal.get("amount", 0) or 0)
        except:
            amount = 0
        if amount > 0:
            return deal
    return None

def update_deal_stage(deal_id, new_stage_id=DEFAULT_DEAL_STAGE_ID):
    url = f"{BASE_URL}api/deals/{deal_id}"
    payload = {
        "deal": {
            "deal_stage_id": new_stage_id
        }
    }
    response = requests.put(url, headers=HEADERS, json=payload)
    if response.status_code == 200:
        print(f"Affaire {deal_id} mise à jour vers 'Retard / Impayé'")
    else:
        print(f"Erreur mise à jour affaire {deal_id}: {response.text}")

def main():
    print("Pause 1/2 : 1 heure avant la récupération des contacts...")
    time.sleep(60)

    existing_contacts = get_existing_contacts()

    with open('azfsdtordzer_impayer.csv', 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        bitrix_contacts = list(reader)

    print("Pause 2/2 : 1 heure avant la mise à jour des affaires...")
    time.sleep(3600)

    for contact in bitrix_contacts:
        email = contact.get('Email', '').strip().lower()
        if not email:
            continue
        if email in existing_contacts:
            contact_id = existing_contacts[email]
            deal = get_existing_deal(contact_id)
            if deal:
                update_deal_stage(deal['id'])
        time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# Pause 1/2 : 1 heure avant la récupération des contacts...
#
# Récupération des contacts existants (email)...
# 38730 contacts récupérés.
# Pause 2/2 : 1 heure avant la mise à jour des affaires...
# Affaire 31004903613 mise à jour vers 'Retard / Impayé'
# Affaire 31003046178 mise à jour vers 'Retard / Impayé'
# Affaire 31003046092 mise à jour vers 'Retard / Impayé'
# Affaire 31003046195 mise à jour vers 'Retard / Impayé'
# Affaire 31003828996 mise à jour vers 'Retard / Impayé'
# Affaire 31003046157 mise à jour vers 'Retard / Impayé'
# Affaire 31005213442 mise à jour vers 'Retard / Impayé'
# Affaire 31003507382 mise à jour vers 'Retard / Impayé'
# Affaire 31005891536 mise à jour vers 'Retard / Impayé'
# Affaire 31005904425 mise à jour vers 'Retard / Impayé'
# Affaire 31004029843 mise à jour vers 'Retard / Impayé'
# Affaire 31005949572 mise à jour vers 'Retard / Impayé'
# Affaire 31003030504 mise à jour vers 'Retard / Impayé'
# Affaire 31005756471 mise à jour vers 'Retard / Impayé'
# Affaire 31005949540 mise à jour vers 'Retard / Impayé'
# Affaire 31005212978 mise à jour vers 'Retard / Impayé'
# Affaire 31005201409 mise à jour vers 'Retard / Impayé'
# Affaire 31003032093 mise à jour vers 'Retard / Impayé'
# Affaire 31004005321 mise à jour vers 'Retard / Impayé'
# Affaire 31005949607 mise à jour vers 'Retard / Impayé'
# Affaire 31003032085 mise à jour vers 'Retard / Impayé'
# Affaire 31003815755 mise à jour vers 'Retard / Impayé'
# Affaire 31005949561 mise à jour vers 'Retard / Impayé'
# Affaire 31003030540 mise à jour vers 'Retard / Impayé'
# Affaire 31005205064 mise à jour vers 'Retard / Impayé'
# Affaire 31003484442 mise à jour vers 'Retard / Impayé'
# Affaire 31005928379 mise à jour vers 'Retard / Impayé'
# Affaire 31005201102 mise à jour vers 'Retard / Impayé'
# Affaire 31003030555 mise à jour vers 'Retard / Impayé'
# Affaire 31004070809 mise à jour vers 'Retard / Impayé'
# Affaire 31003032184 mise à jour vers 'Retard / Impayé'
# Affaire 31003030323 mise à jour vers 'Retard / Impayé'
# Affaire 31004003251 mise à jour vers 'Retard / Impayé'
# Affaire 31003030434 mise à jour vers 'Retard / Impayé'
# Affaire 31004020531 mise à jour vers 'Retard / Impayé'
# Affaire 31003032091 mise à jour vers 'Retard / Impayé'
# Affaire 31003030494 mise à jour vers 'Retard / Impayé'
# Affaire 31005805668 mise à jour vers 'Retard / Impayé'
# Affaire 31005211389 mise à jour vers 'Retard / Impayé'
# Affaire 31005755919 mise à jour vers 'Retard / Impayé'
# Affaire 31003834157 mise à jour vers 'Retard / Impayé'
# Affaire 31005928142 mise à jour vers 'Retard / Impayé'
# Affaire 31004634397 mise à jour vers 'Retard / Impayé'
# Affaire 31003517547 mise à jour vers 'Retard / Impayé'
# Affaire 31003030491 mise à jour vers 'Retard / Impayé'
# Affaire 31003030329 mise à jour vers 'Retard / Impayé'
# Affaire 31005971496 mise à jour vers 'Retard / Impayé'
# Affaire 31004033912 mise à jour vers 'Retard / Impayé'
# Affaire 31003030516 mise à jour vers 'Retard / Impayé'
# Affaire 31003032286 mise à jour vers 'Retard / Impayé'
# Affaire 31006111817 mise à jour vers 'Retard / Impayé'
# Affaire 31003031189 mise à jour vers 'Retard / Impayé'
# Affaire 31003588180 mise à jour vers 'Retard / Impayé'
# Affaire 31003030376 mise à jour vers 'Retard / Impayé'
# Affaire 31003030345 mise à jour vers 'Retard / Impayé'
# Affaire 31004071530 mise à jour vers 'Retard / Impayé'
# Affaire 31003046173 mise à jour vers 'Retard / Impayé'
# Affaire 31005750828 mise à jour vers 'Retard / Impayé'
# Affaire 31005200910 mise à jour vers 'Retard / Impayé'
# Affaire 31004001892 mise à jour vers 'Retard / Impayé'

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Suivi de l’évolution des statuts des factures MPA Facture Annulée</span>

# %%
import pandas as pd

df = pd.read_csv('azfsdtord.csv')

filtré = df[df['Statut récent'].str.contains('Annulée', case=False, na=False)]

filtré.to_csv("azfsdtordzer_Annulée.csv", index=False)
filtré

# %%
import csv
import requests
import time

API_KEY_FRESHWORK = ''
DOMAIN_FRESHWORK = ''
BASE_URL = f'https://{DOMAIN_FRESHWORK}.myfreshworks.com/crm/sales/'

HEADERS = {
    'Content-Type': 'application/json',
    'Authorization': f'Token token={API_KEY_FRESHWORK}'
}

DEFAULT_DEAL_STAGE_ID = 31001026962

def get_existing_contacts():
    print("\nRécupération des contacts existants (email)...")
    all_contacts = {}
    page = 1
    while True:
        url = f"{BASE_URL}api/contacts/view/31004512042?sort=created_at&per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Erreur contacts: {response.text}")
            return {}
        contacts_data = response.json().get("contacts", [])
        if not contacts_data:
            break
        for contact in contacts_data:
            email = contact.get("email")
            if email:
                all_contacts[email.strip().lower()] = contact["id"]
        page += 1
        time.sleep(1)
    print(f"{len(all_contacts)} contacts récupérés.")
    return all_contacts

def get_existing_deal(contact_id):
    url = f"{BASE_URL}api/contacts/{contact_id}/deals"
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Erreur récupération des affaires pour contact {contact_id}")
        return None
    deals = response.json().get("deals", [])
    for deal in deals:
        try:
            amount = float(deal.get("amount", 0) or 0)
        except:
            amount = 0
        if amount > 0:
            return deal
    return None

def update_deal_stage(deal_id, new_stage_id=DEFAULT_DEAL_STAGE_ID):
    url = f"{BASE_URL}api/deals/{deal_id}"
    payload = {
        "deal": {
            "deal_stage_id": new_stage_id
        }
    }
    response = requests.put(url, headers=HEADERS, json=payload)
    if response.status_code == 200:
        print(f"Affaire {deal_id} mise à jour vers 'MPA Annulée'")
    else:
        print(f"Erreur mise à jour affaire {deal_id}: {response.text}")

def main():
    print("Pause 1/2 : 1 heure avant la récupération des contacts...")
    time.sleep(3600)

    existing_contacts = get_existing_contacts()

    with open('azfsdtordzer_Annulée.csv', 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        bitrix_contacts = list(reader)

    print("Pause 2/2 : 1 heure avant la mise à jour des affaires...")
    time.sleep(1)

    for contact in bitrix_contacts:
        email = contact.get('Email', '').strip().lower()
        if not email:
            continue
        if email in existing_contacts:
            contact_id = existing_contacts[email]
            deal = get_existing_deal(contact_id)
            if deal:
                update_deal_stage(deal['id'])
        time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# Pause 1/2 : 1 heure avant la récupération des contacts...
#
# Récupération des contacts existants (email)...
# 38731 contacts récupérés.
# Pause 2/2 : 1 heure avant la mise à jour des affaires...
# Affaire 31004052729 mise à jour vers 'MPA Annulée'
# Affaire 31004069719 mise à jour vers 'MPA Annulée'
# Affaire 31004070830 mise à jour vers 'MPA Annulée'
# Affaire 31005206282 mise à jour vers 'MPA Annulée'
# Affaire 31003665581 mise à jour vers 'MPA Annulée'
# Affaire 31005216667 mise à jour vers 'MPA Annulée'
# Affaire 31005214882 mise à jour vers 'MPA Annulée'
# Affaire 31003030495 mise à jour vers 'MPA Annulée'
# Affaire 31003869605 mise à jour vers 'MPA Annulée'
# Affaire 31005214924 mise à jour vers 'MPA Annulée'
# Affaire 31005205920 mise à jour vers 'MPA Annulée'
# Affaire 31003031449 mise à jour vers 'MPA Annulée'
# Affaire 31005209956 mise à jour vers 'MPA Annulée'
# Affaire 31004031915 mise à jour vers 'MPA Annulée'
# Affaire 31003514541 mise à jour vers 'MPA Annulée'
# Affaire 31005370691 mise à jour vers 'MPA Annulée'
# Affaire 31005847780 mise à jour vers 'MPA Annulée'
# Affaire 31004004839 mise à jour vers 'MPA Annulée'
# Affaire 31005928512 mise à jour vers 'MPA Annulée'
# Affaire 31005211002 mise à jour vers 'MPA Annulée'
# Affaire 31004026940 mise à jour vers 'MPA Annulée'
# Affaire 31005754807 mise à jour vers 'MPA Annulée'
# Affaire 31005755031 mise à jour vers 'MPA Annulée'
# Affaire 31005949602 mise à jour vers 'MPA Annulée'
# Affaire 31005860870 mise à jour vers 'MPA Annulée'
# Affaire 31003832159 mise à jour vers 'MPA Annulée'
# Affaire 31005215027 mise à jour vers 'MPA Annulée'
# Affaire 31003046186 mise à jour vers 'MPA Annulée'
# Affaire 31003032097 mise à jour vers 'MPA Annulée'
# Affaire 31005754987 mise à jour vers 'MPA Annulée'
# Affaire 31005949634 mise à jour vers 'MPA Annulée'
# Affaire 31003032313 mise à jour vers 'MPA Annulée'
# Affaire 31005211236 mise à jour vers 'MPA Annulée'
# Affaire 31006020442 mise à jour vers 'MPA Annulée'
# Affaire 31004006888 mise à jour vers 'MPA Annulée'
# Affaire 31005928473 mise à jour vers 'MPA Annulée'
# Affaire 31005847780 mise à jour vers 'MPA Annulée'
# Affaire 31005204597 mise à jour vers 'MPA Annulée'
# Affaire 31005539655 mise à jour vers 'MPA Annulée'
# Affaire 31005855455 mise à jour vers 'MPA Annulée'
# Affaire 31003031465 mise à jour vers 'MPA Annulée'
# Affaire 31005215061 mise à jour vers 'MPA Annulée'
# Affaire 31005214723 mise à jour vers 'MPA Annulée'
# Affaire 31005209338 mise à jour vers 'MPA Annulée'
# Affaire 31005755501 mise à jour vers 'MPA Annulée'
# Affaire 31005751275 mise à jour vers 'MPA Annulée'
# Affaire 31005583712 mise à jour vers 'MPA Annulée'
# Affaire 31005949577 mise à jour vers 'MPA Annulée'
# Affaire 31004007930 mise à jour vers 'MPA Annulée'
# Affaire 31005216648 mise à jour vers 'MPA Annulée'
# Affaire 31004074558 mise à jour vers 'MPA Annulée'
# Affaire 31005539032 mise à jour vers 'MPA Annulée'
# Affaire 31003989749 mise à jour vers 'MPA Annulée'

# %% [markdown]
# <span style="color: white; font-weight: bold; font-size: 50px;">Acuity</span>

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import datetime
import time

USER_ID = ''
API_KEY = ''

def get_appointments_in_range(start_date, end_date):
    url = f"https://acuityscheduling.com/api/v1/appointments?minDate={start_date}&maxDate={end_date}&showall=true"
    response = requests.get(url, auth=HTTPBasicAuth(USER_ID, API_KEY))
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Erreur API pour la période {start_date} à {end_date} : {response.status_code}")
        return []

def get_appointment_by_id(appointment_id):
    url = f"https://acuityscheduling.com/api/v1/appointments/{appointment_id}"
    response = requests.get(url, auth=HTTPBasicAuth(USER_ID, API_KEY))
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Erreur lors de la récupération du RDV ID {appointment_id}")
        return None

def daterange(start_date, end_date, step_days=7):
    while start_date <= end_date:
        yield start_date, min(end_date, start_date + datetime.timedelta(days=step_days - 1))
        start_date += datetime.timedelta(days=step_days)

def collect_all_appointments():
    all_data = []
    seen_ids = set()
    start = datetime.date(2025, 4, 1)
    end = datetime.date(2025, 12, 31)

    print("Début de la collecte des rendez-vous")

    for start_date, end_date in daterange(start, end):
        print(f"\nPériode : {start_date} à {end_date}")
        appointments = get_appointments_in_range(start_date, end_date)
        print(f"{len(appointments)} rendez-vous trouvés.")

        for appt in appointments:
            appt_id = appt.get("id")
            if appt_id in seen_ids:
                continue
            seen_ids.add(appt_id)

            details = get_appointment_by_id(appt_id)
            if details:
                appt["scheduledBy"] = details.get("scheduledBy", "Non spécifié")
            else:
                appt["scheduledBy"] = "Non spécifié"

            nom = f"{appt.get('lastName', '')} {appt.get('firstName', '')}".strip()
            date = appt.get('date', 'Date inconnue')
            heure = appt.get('time', 'Heure inconnue')
            type_rdv = appt.get('type', 'Type inconnu')
            calendrier = appt.get('calendar', 'Calendrier inconnu')

            print(f"  RDV ID {appt_id} | {nom} - {date} {heure} - {type_rdv} - Calendrier: {calendrier} - Créé par: {appt['scheduledBy']}")

            all_data.append(appt)
            time.sleep(0.2)

        time.sleep(0.5)

    print(f"\nCollecte terminée. Total RDV : {len(all_data)}")
    return all_data

def to_dataframe(data):
    rows = []
    for item in data:
        rows.append({
            "Nom": f"{item.get('lastName', '')} {item.get('firstName', '')}".strip(),
            "Email": item.get('email', ''),
            "Téléphone": item.get('phone', ''),
            "Date de création": item.get('datetimeCreated', ''),
            "Date du RDV": item.get('date', ''),
            "Heure": item.get('time', ''),
            "Type de RDV": item.get('type', ''),
            "Calendrier": item.get('calendar', ''),
            "Créé par": item.get('scheduledBy', ''),
        })
    return pd.DataFrame(rows)

def save_csv(df):
    filename = "acuity_rdv_2024_2025.csv"
    df.to_csv(filename, index=False, encoding="utf-8")
    print(f"\nFichier exporté : {filename}")

if __name__ == "__main__":
    data = collect_all_appointments()
    df = to_dataframe(data)
    save_csv(df)
# Out:
# Début de la collecte des rendez-vous
#
# Période : 2025-04-01 à 2025-04-07
# 47 rendez-vous trouvés.
#   RDV ID 1444404503 | Renoux Caroline - April 7, 2025 16:30 - Mise en place administrative accompagnement Oser le changement - Calendrier: Aurélie en télé-présentiel - Créé par: evaluation@institutadios.com
#   RDV ID 1442061675 | Mendel Antoine - April 7, 2025 16:00 - Session de 3h en visio-consultation à l'unité SarahNacass.com - Calendrier: Praticien(ne) Sarah Nacass via Zoom - Créé par: contact@sarahnacass.com
#   RDV ID 1443209596 | Briand Vincent - April 7, 2025 14:00 - Activation du changement de 3h avec un(e) praticien(ne) expérimenté(e) sur place n°rdv.oserlechangement - Calendrier: Praticien(ne) Oser le Changement en activation du changement sur Place - Créé par: accueil@institutadios.com
#   RDV ID 1445720414 | Lacarotte Jo - April 7, 2025 13:00 - Session de 3h sur place à l'unité - Calendrier: Praticien(ne) Sarah Nacass sur Place - Créé par: contact@sarahnacass.com
#   RDV ID 1441572965 | Carotte de l'espace Joe la - April 7, 2025 12:00 - Institut ADIOS sur place - 1ère Séance initiale et mise en place d'un accompagnement n°institutadios - Calendrier: Praticien(ne) expérimenté(e) Adios - Créé par: rdvpointinstitutadiospointcom@institutadios.com
#   RDV ID 1447813550 | Ma hado Jenny - April 7, 2025 11:15 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: accueil@institutadios.com
#   RDV ID 1443209660 | Blot Marc - April 7, 2025 11:00 - Activation du changement de 3h avec un(e) praticien(ne) expérimenté(e) sur place n°rdv.oserlechangement - Calendrier: Praticien(ne) Oser le Changement en activation du changement sur Place - Créé par: accueil@institutadios.com
#   RDV ID 1444183082 | Paumier Laetitia - April 7, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 1 jour ) - Lundi ou Jeudi n°stage.osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavina - Créé par: accueil@institutadios.com
#   RDV ID 1448397135 | Magalie Herche - April 7, 2025 10:00 - Rdv Addiction visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: general@sarahnacass.com
#   RDV ID 1445539137 | CHIVA Franck - April 7, 2025 09:30 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: accueil@institutadios.com
#   RDV ID 1441557930 | Carotte de l'espace Joe la - April 7, 2025 09:00 - Institut ADIOS sur place - 1ère Séance initiale et mise en place d'un accompagnement n°institutadios - Calendrier: Praticien(ne) expérimenté(e) Adios - Créé par: rdvpointinstitutadiospointcom@institutadios.com
#   RDV ID 1445541783 | Raton Thomas - April 7, 2025 09:00 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1448783310 | Traore-Samake Bakary - April 5, 2025 12:45 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1446373806 | Rabot CHristelle - April 5, 2025 09:00 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1447472985 | Umek Priscilla - April 4, 2025 18:15 - Activation du changement de 3h avec un(e) praticien(ne) expérimenté(e) en visio-consultation n°rdv.oserlechangement - Calendrier: Praticien(ne) Oser le Changement en activation du changement via Zoom - Créé par: accueil@institutadios.com
#   RDV ID 1445553490 | Sebastien Bachir-BEY - April 4, 2025 11:00 - Session de 3h sur place à l'unité - Calendrier: Praticien(ne) expérimenté(e) sur Beauvais - Créé par: contact@sarahnacass.com
#   RDV ID 1447054308 | Bekhaitia Khedija - April 4, 2025 08:30 - Activation du changement de 3h avec un(e) praticien(ne) expérimenté(e) en visio-consultation n°rdv.oserlechangement - Calendrier: Praticien(ne) Oser le Changement en activation du changement via Zoom - Créé par: accueil@institutadios.com
#   RDV ID 1446515436 | salim AURORE - April 4, 2025 08:00 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1446083452 | Maisiat Catherine - April 3, 2025 15:00 - Activation du changement de 3h avec un(e) praticien(ne) expérimenté(e) en visio-consultation n°rdv.oserlechangement - Calendrier: Praticien(ne) Oser le Changement en activation du changement via Zoom - Créé par: accueil@institutadios.com
#   RDV ID 1446462130 | KEDDAD Halima - April 3, 2025 13:15 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1446672725 | Lefebvre Pierre - April 3, 2025 13:00 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: accueil@institutadios.com
#   RDV ID 1440074118 | Schipper Marielle - April 3, 2025 11:00 - Activation du changement de 3h avec un(e) praticien(ne) expérimenté(e) sur place n°rdv.oserlechangement - Calendrier: Praticien(ne) Oser le Changement en activation du changement sur Place - Créé par: accueil@institutadios.com
#   RDV ID 1447141912 | Roseline Biaou - April 3, 2025 11:00 - RDV ⁠Alcool via visio d'information préalable - Calendrier: Aurélie en télé-présentiel - Créé par: contact@sarahnacass.com
#   RDV ID 1444884229 | Ferreira Shirley - April 3, 2025 10:30 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1447193866 | So Coumba - April 3, 2025 10:15 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1441547652 | Chafek Laouani - April 3, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants (  1 jour ) lundi ou jeudi - association Osez Le Changement - Calendrier: Jessica Tiavina - Créé par: contact@sarahnacass.com
#   RDV ID 1443458124 | D'argruma jean-marc - April 3, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants (  1 jour ) lundi ou jeudi - association Osez Le Changement - Calendrier: Jessica Tiavina - Créé par: general@sarahnacass.com
#   RDV ID 1446467592 | test test - April 3, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 1 jour ) - Lundi ou Jeudi n°stage.osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavi - Créé par: accueil@sarahnacass.com
#   RDV ID 1446511341 | Konatetest Issa - April 3, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 1 jour ) - Lundi ou Jeudi n°stage.sensibilisation-stupefiants.fr - Association Osez Le Changement - Calendrier: Jessica Tiavi - Créé par: accueil
30 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1470100540 | Carotte de l'espace Joe la - May 13, 2025 13:30 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: accueil@institutadios.com
#   RDV ID 1470069720 | la carotte Jo - May 13, 2025 11:00 - Séance Préalable OFFERTE - Calendrier: Raphaelle en télé-présentiel - Créé par: contact@sarahnacass.com
#   RDV ID 1466556423 | Dhont Arnaud - May 13, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 2 jours ) - Mardi et Mercredi ou Vendredi et Samedi n°stage.osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavina - Créé par: accueil@institutadios.com
#   RDV ID 1468334475 | Dhont Arnaud - May 13, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 2 jours ) - Mardi et Mercredi ou Vendredi et Samedi n°osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavi - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1468346006 | Dhont Arnaud - May 13, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 2 jours ) - Mardi et Mercredi ou Vendredi et Samedi n°stage.osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavina - Créé par: accueil@institutadios.com
#   RDV ID 1462208476 | aa aa - May 13, 2025 09:00 - RDV via visio d'information préalable avec un conseiller - Calendrier: Aurélie en télé-présentiel - Créé par: accueil@institutadios.com
#
# Période : 2025-05-20 à 2025-05-26
# 8 rendez-vous trouvés.
#   RDV ID 1467966634 | gailliard pierrick - May 24, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 2 jours ) - Mardi et Mercredi ou Vendredi et Samedi n°stage.osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavi - Créé par: accueil@institutadios.com
#   RDV ID 1467968333 | gailliard pierrick - May 24, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 2 jours ) - Mardi et Mercredi ou Vendredi et Samedi n°stage.osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavina - Créé par: accueil@institutadios.com
#   RDV ID 1467966361 | gailliard pierrick - May 23, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 2 jours ) - Mardi et Mercredi ou Vendredi et Samedi n°stage.osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavina - Créé par: accueil@institutadios.com
#   RDV ID 1467967986 | gailliard pierrick - May 23, 2025 10:00 - Stage de sensibilisation aux dangers de l'usage de produits stupéfiants ( 2 jours ) - Mardi et Mercredi ou Vendredi et Samedi n°stage.osezlechangement.org - Association Osez Le Changement - Calendrier: Jessica Tiavi - Créé par: accueil@institutadios.com
#   RDV ID 1469654619 | Henry Véronique - May 22, 2025 11:00 - Mise en place administrative préalable au résidentiel n°oserlechangement - Calendrier: Aurélie en télé-présentiel - Créé par: rdvenligne@oserlechangement.com
#   RDV ID 1467215958 | Moreau Florent - May 21, 2025 10:30 - Session de 3h en visio-consultation à l'unité SarahNacass.com - Calendrier: Praticien(ne) Sarah Nacass via Zoom - Créé par: contact@sarahnacass.com
#   RDV ID 1468213480 | Palayer Murielle - May 20, 2025 11:00 - Activation du changement de 3h avec un(e) praticien(ne) expérimenté(e) sur place n°rdv.oserlechangement - Calendrier: Praticien(ne) Oser le Changement en activation du changement sur Place - Créé par: accueil@institutadios.com
#   RDV ID 1469547799 | Adrien Rousseil - May 20, 2025 10:00 - Mise en place administrative accompagnement Oser le changement - Calendrier: Aurélie en télé-présentiel - Créé par: contact@sarahnacass.com
#
# Période : 2025-05-27 à 2025-06-02
# 0 rendez-vous trouvés.
#
# Période : 2025-06-03 à 2025-06-09
# 0 rendez-vous trouvés.
#
# Période : 2025-06-10 à 2025-06-16
# 0 rendez-vous trouvés.
#
# Période : 2025-06-17 à 2025-06-23
# 0 rendez-vous trouvés.
#
# Période : 2025-06-24 à 2025-06-30
# 0 rendez-vous trouvés.
#
# Période : 2025-07-01 à 2025-07-07
# 0 rendez-vous trouvés.
#
# Période : 2025-07-08 à 2025-07-14
# 0 rendez-vous trouvés.
#
# Période : 2025-07-15 à 2025-07-21
# 0 rendez-vous trouvés.
#
# Période : 2025-07-22 à 2025-07-28
# 0 rendez-vous trouvés.
#
# Période : 2025-07-29 à 2025-08-04
# 0 rendez-vous trouvés.
#
# Période : 2025-08-05 à 2025-08-11
# 0 rendez-vous trouvés.
#
# Période : 2025-08-12 à 2025-08-18
# 0 rendez-vous trouvés.
#
# Période : 2025-08-19 à 2025-08-25
# 0 rendez-vous trouvés.
#
# Période : 2025-08-26 à 2025-09-01
# 0 rendez-vous trouvés.
#
# Période : 2025-09-02 à 2025-09-08
# 0 rendez-vous trouvés.
#
# Période : 2025-09-09 à 2025-09-15
# 0 rendez-vous trouvés.
#
# Période : 2025-09-16 à 2025-09-22
# 0 rendez-vous trouvés.
#
# Période : 2025-09-23 à 2025-09-29
# 0 rendez-vous trouvés.
#
# Période : 2025-09-30 à 2025-10-06
# 0 rendez-vous trouvés.
#
# Période : 2025-10-07 à 2025-10-13
# 0 rendez-vous trouvés.
#
# Période : 2025-10-14 à 2025-10-20
# 0 rendez-vous trouvés.
#
# Période : 2025-10-21 à 2025-10-27
# 0 rendez-vous trouvés.
#
# Période : 2025-10-28 à 2025-11-03
# 0 rendez-vous trouvés.
#
# Période : 2025-11-04 à 2025-11-10
# 0 rendez-vous trouvés.
#
# Période : 2025-11-11 à 2025-11-17
# 0 rendez-vous trouvés.
#
# Période : 2025-11-18 à 2025-11-24
# 0 rendez-vous trouvés.
#
# Période : 2025-11-25 à 2025-12-01
# 0 rendez-vous trouvés.
#
# Période : 2025-12-02 à 2025-12-08
# 0 rendez-vous trouvés.
#
# Période : 2025-12-09 à 2025-12-15
# 0 rendez-vous trouvés.
#
# Période : 2025-12-16 à 2025-12-22
# 0 rendez-vous trouvés.
#
# Période : 2025-12-23 à 2025-12-29
# 0 rendez-vous trouvés.
#
# Période : 2025-12-30 à 2025-12-31
# 0 rendez-vous trouvés.
#
# Collecte terminée. Total RDV : 286
#
# Fichier exporté : acuity_rdv_2024_2025.csv

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import datetime
import time

df1 = pd.read_csv("acuity_rdv_2024_2025.csv")
df1["Mobile"]=df1["Téléphone"]
del df1["Téléphone"]
print(f"\033[31mNombre de rendez-vous total du 1/1/2024-2025 : {len(df1)}\033[0m")
df1.to_csv("acuity_appointments_MPA_2025.csv", index=False)
df1

# %%
import pandas as pd


df1 = pd.read_csv("acuity_rdv_2024_2025.csv")


df1 = df1[~df1["Nom"].str.contains("carotte|test", case=False, na=False)]

b = df1.loc[df1["Type de RDV"].str.contains(
    "Mise en place ad",
    regex=False
)]

print(f"\033[31mNombre de rendez-vous trouvés : {len(b)}\033[0m")

b.to_csv("MPA_prévue.csv", index=False)

b

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Suivi de l’évolution des statuts des factures MPA</span>

# %%
import pandas as pd

acuity = pd.read_csv('MPA_prévue.csv', dtype=str)
sellsy = pd.read_csv('azfsdtord.csv', dtype=str)

acuity['Email'] = acuity['Email'].str.strip().str.lower()
sellsy['Email'] = sellsy['Email'].str.strip().str.lower()

acuity_unique = acuity[~acuity['Email'].isin(sellsy['Email'])]

print(f"{len(acuity_unique)} emails trouvés dans Acuity mais absents de Sellsy :")
print(acuity_unique[['Email']].drop_duplicates())

acuity_unique.to_csv('emails_absents_de_sellsy_MPA.csv', index=False)
acuity_unique

# %%
import csv
import requests
import time
import uuid

API_KEY_FRESHWORK = ''
DOMAIN_FRESHWORK = ''
BASE_URL = f'https://{DOMAIN_FRESHWORK}.myfreshworks.com/crm/sales/'

HEADERS = {
    'Content-Type': 'application/json',
    'Authorization': f'Token token={API_KEY_FRESHWORK}'
}

DEFAULT_DEAL_STAGE_ID = 31000543862

def generate_cf_id_bitrix():
    """Génère un identifiant unique pour cf_id_bitrix."""
    return str(uuid.uuid4())

def truncate(text, max_length):
    return text[:max_length] if text else ""

def get_existing_contacts():
    print("\nRécupération des contacts existants (email)...")
    all_contacts = {}
    page = 1
    while True:
        url = f"{BASE_URL}api/contacts/view/31004512042?sort=created_at&per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Erreur contacts: {response.text}")
            return {}
        contacts_data = response.json().get("contacts", [])
        if not contacts_data:
            break
        for contact in contacts_data:
            email = contact.get("email")
            if email:
                all_contacts[email.strip().lower()] = contact["id"]
        page += 1
        time.sleep(1)
    print(f"{len(all_contacts)} contacts récupérés.")
    return all_contacts

def get_existing_deal(contact_id):
    url = f"{BASE_URL}api/contacts/{contact_id}/deals"
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Erreur récupération des affaires pour contact {contact_id}")
        return None
    deals = response.json().get("deals", [])
    for deal in deals:
        try:
            amount = float(deal.get("amount", 0) or 0)
        except:
            amount = 0
        if amount > 0:
            return deal
    return None

def update_deal_stage(deal_id, new_stage_id=DEFAULT_DEAL_STAGE_ID):
    url = f"{BASE_URL}api/deals/{deal_id}"
    payload = {
        "deal": {
            "deal_stage_id": new_stage_id
        }
    }
    response = requests.put(url, headers=HEADERS, json=payload)
    if response.status_code == 200:
        print(f"Affaire {deal_id} mise à jour vers 'MPA prévue'")
    else:
        print(f"Erreur mise à jour affaire {deal_id}: {response.text}")

def create_deal_for_contact(contact_id):
    url = f"{BASE_URL}api/deals"
    payload = {
        "deal": {
            "name": "Affaire générée automatiquement",
            "contacts_added_list": [contact_id],
            "amount": 0,
            "deal_stage_id": DEFAULT_DEAL_STAGE_ID
        }
    }
    response = requests.post(url, headers=HEADERS, json=payload)
    if response.status_code == 201:
        print(f"Affaire créée pour le contact {contact_id}")
        return response.json().get("deal", {})
    else:
        print(f"Erreur création affaire pour le contact {contact_id}: {response.text}")
        return None

def create_contact(row):
    """Créer un contact depuis le CSV avec tous les champs nécessaires."""
    email = row.get("Email", "").strip().lower()
    last_name = row.get("Nom", "").strip()
    action = row.get("Type de RDV", "").strip()
    mobile = row.get("Téléphone", "").strip()
    date_creation = row.get("Date de création", "").strip()
    cf_id_bitrix = row.get("cf_id_bitrix", "").strip() or generate_cf_id_bitrix()

    payload = {
        "contact": {
            "last_name": last_name,
            "email": email,
            "mobile_number": mobile,
            "custom_field": {
                "cf_id_bitrix": cf_id_bitrix,
                "cf_action_initiale_du_prospect": action,
                "cf_date_de_creation": date_creation,
            }
        }
    }

    print(f"Création du contact : {last_name} <{email}> (bitrix ID: {cf_id_bitrix})")
    url = f"{BASE_URL}api/contacts"
    response = requests.post(url, headers=HEADERS, json=payload)
    if response.status_code == 201:
        contact_id = response.json()['contact']['id']
        print(f"Contact créé (ID: {contact_id})")
        return contact_id
    else:
        print(f"Erreur création contact : {response.text}")
        return None


def main():
    existing_contacts = get_existing_contacts()

    with open('emails_absents_de_sellsy_MPA.csv', 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        bitrix_contacts = list(reader)

    for contact in bitrix_contacts:
        email = contact.get('Email', '').strip().lower()
        if not email:
            continue

        if email in existing_contacts:
            contact_id = existing_contacts[email]
            deal = get_existing_deal(contact_id)
            if deal:
                update_deal_stage(deal['id'])
            else:
                create_deal_for_contact(contact_id)
        else:
            contact_id = create_contact(contact)
            if contact_id:
                existing_contacts[email] = contact_id 
                create_deal_for_contact(contact_id)

        time.sleep(1)


if __name__ == "__main__":
    main()
# Out:
# Récupération des contacts existants (email)...
# 38729 contacts récupérés.
# Erreur création affaire pour le contact 31118050766: {"users":[{"id":31000890026,"display_name":"James Aurelie","email":"accueil@sarahnacass.com","is_active":true,"work_number":null,"mobile_number":null}],"deal":{"id":31006921089,"name":"Affaire générée automatiquement","amount":"0.0","base_currency_amount":"0.0","expected_close":null,"closed_date":null,"stage_updated_time":"2025-05-12T15:55:22+02:00","custom_field":{"cf_transaction":null,"cf_activit":null,"cf_statut_du_paiement":null,"cf_statut_de_livraison":null,"cf_types":null,"cf_sources":null,"cf_information_sur_la_source":null,"cf_chemin_du_client":null,"cf_url_de_la_source":null,"cf_score":null,"cf_objectif_formul":null,"cf_date_de_naissance":null,"cf_budget_journalier_utm_medium":null,"cf_action_initiale_du_prospect":null,"cf_etapes_de_la_transaction":null,"cf_date_de_creation":null,"cf_etapes_de_formation":null,"cf_id_bitrix":null,"cf_mobile":null,"cf_email":null,"cf_valeur_de_laffaire_2":null},"probability":50,"updated_at":"2025-05-12T15:55:22+02:00","created_at":"2025-05-12T15:55:22+02:00","deal_pipeline_id":31000077536,"deal_stage_id":31000543862,"age":0,"links":{"conversations":"/crm/sales/deals/31006921089/conversations/all?include=email_conversation_recipients%2Ctargetable%2Cphone_number%2Cphone_caller%2Cnote%2Cuser\u0026per_page=3","document_associations":"/crm/sales/deals/31006921089/document_associations","notes":"/crm/sales/deals/31006921089/notes?include=creater","tasks":"/crm/sales/deals/31006921089/tasks?include=creater,owner,updater,targetable,users,task_type","appointments":"/crm/sales/deals/31006921089/appointments?include=creater,owner,updater,targetable,appointment_attendees,conference,note"},"recent_note":null,"completed_sales_sequences":null,"active_sales_sequences":null,"web_form_id":null,"upcoming_activities_time":null,"collaboration":{},"last_assigned_at":null,"last_contacted_sales_activity_mode":null,"last_contacted_via_sales_activity":null,"expected_deal_value":"0.0","is_deleted":false,"team_user_ids":null,"avatar":null,"fc_widget_collaboration":{"convo_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJDb252b0lkIjoiMzEwMDY5MjEwODkiLCJ0eXBlIjoiZGVhbCJ9.CATeROjr13uU62tLvK4qJcgsn14_4Ow6b-Q3_23X9R0","auth_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJVc2VyVVVJRCI6IjU5NDI3NzY4MTIwMzkyMzY2NCJ9.tVm7b6vZJUzA5Bk1FaSWvkm5wcl_W3DhDAQE-NgdtSE","encoded_jwt_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..dsyv0QNQFNsrJ7mygS988Ug6FZ6Y5d6O16WUCCrZHhM"},"forecast_category":null,"deal_prediction":0,"deal_prediction_last_updated_at":null,"freddy_forecast_metrics":null,"last_deal_prediction":null,"has_products":false,"products":[],"deal_price_adjustments":[],"rotten_days":null,"tags":[],"creater_id":31000890026}}
# Erreur création affaire pour le contact 31122450981: {"users":[{"id":31000890026,"display_name":"James Aurelie","email":"accueil@sarahnacass.com","is_active":true,"work_number":null,"mobile_number":null}],"deal":{"id":31006921090,"name":"Affaire générée automatiquement","amount":"0.0","base_currency_amount":"0.0","expected_close":null,"closed_date":null,"stage_updated_time":"2025-05-12T15:55:23+02:00","custom_field":{"cf_transaction":null,"cf_activit":null,"cf_statut_du_paiement":null,"cf_statut_de_livraison":null,"cf_types":null,"cf_sources":null,"cf_information_sur_la_source":null,"cf_chemin_du_client":null,"cf_url_de_la_source":null,"cf_score":null,"cf_objectif_formul":null,"cf_date_de_naissance":null,"cf_budget_journalier_utm_medium":null,"cf_action_initiale_du_prospect":null,"cf_etapes_de_la_transaction":null,"cf_date_de_creation":null,"cf_etapes_de_formation":null,"cf_id_bitrix":null,"cf_mobile":null,"cf_email":null,"cf_valeur_de_laffaire_2":null},"probability":50,"updated_at":"2025-05-12T15:55:23+02:00","created_at":"2025-05-12T15:55:23+02:00","deal_pipeline_id":31000077536,"deal_stage_id":31000543862,"age":0,"links":{"conversations":"/crm/sales/deals/31006921090/conversations/all?include=email_conversation_recipients%2Ctargetable%2Cphone_number%2Cphone_caller%2Cnote%2Cuser\u0026per_page=3","document_associations":"/crm/sales/deals/31006921090/document_associations","notes":"/crm/sales/deals/31006921090/notes?include=creater","tasks":"/crm/sales/deals/31006921090/tasks?include=creater,owner,updater,targetable,users,task_type","appointments":"/crm/sales/deals/31006921090/appointments?include=creater,owner,updater,targetable,appointment_attendees,conference,note"},"recent_note":null,"completed_sales_sequences":null,"active_sales_sequences":null,"web_form_id":null,"upcoming_activities_time":null,"collaboration":{},"last_assigned_at":null,"last_contacted_sales_activity_mode":null,"last_contacted_via_sales_activity":null,"expected_deal_value":"0.0","is_deleted":false,"team_user_ids":null,"avatar":null,"fc_widget_collaboration":{"convo_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJDb252b0lkIjoiMzEwMDY5MjEwOTAiLCJ0eXBlIjoiZGVhbCJ9.TErryw9cTFOtgvJ1k0cti9VMMoggIeH1XgMHQrTUNAk","auth_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJVc2VyVVVJRCI6IjU5NDI3NzY4MTIwMzkyMzY2NCJ9.tVm7b6vZJUzA5Bk1FaSWvkm5wcl_W3DhDAQE-NgdtSE","encoded_jwt_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..o9pFYkJL10Nmx4QqRaUWWFVF2w66Ks2fFW9RA2Nl7Z8"},"forecast_category":null,"deal_prediction":0,"deal_prediction_last_updated_at":null,"freddy_forecast_metrics":null,"last_deal_prediction":null,"has_products":false,"products":[],"deal_price_adjustments":[],"rotten_days":null,"tags":[],"creater_id":31000890026}}
# Affaire 31006142227 mise à jour vers 'MPA prévue'
# Erreur création affaire pour le contact 31117919282: {"users":[{"id":31000890026,"display_name":"James Aurelie","email":"accueil@sarahnacass.com","is_active":true,"work_number":null,"mobile_number":null}],"deal":{"id":31006921091,"name":"Affaire générée automatiquement","amount":"0.0","base_currency_amount":"0.0","expected_close":null,"closed_date":null,"stage_updated_time":"2025-05-12T15:55:27+02:00","custom_field":{"cf_transaction":null,"cf_activit":null,"cf_statut_du_paiement":null,"cf_statut_de_livraison":null,"cf_types":null,"cf_sources":null,"cf_information_sur_la_source":null,"cf_chemin_du_client":null,"cf_url_de_la_source":null,"cf_score":null,"cf_objectif_formul":null,"cf_date_de_naissance":null,"cf_budget_journalier_utm_medium":null,"cf_action_initiale_du_prospect":null,"cf_etapes_de_la_transaction":null,"cf_date_de_creation":null,"cf_etapes_de_formation":null,"cf_id_bitrix":null,"cf_mobile":null,"cf_email":null,"cf_valeur_de_laffaire_2":null},"probability":50,"updated_at":"2025-05-12T15:55:27+02:00","created_at":"2025-05-12T15:55:27+02:00","deal_pipeline_id":31000077536,"deal_stage_id":31000543862,"age":0,"links":{"conversations":"/crm/sales/deals/31006921091/conversations/all?include=email_conversation_recipients%2Ctargetable%2Cphone_number%2Cphone_caller%2Cnote%2Cuser\u0026per_page=3","document_associations":"/crm/sales/deals/31006921091/document_associations","notes":"/crm/sales/deals/31006921091/notes?include=creater","tasks":"/crm/sales/deals/31006921091/tasks?include=creater,owner,updater,targetable,users,task_type","appointments":"/crm/sales/deals/31006921091/appointments?include=creater,owner,updater,targetable,appointment_attendees,conference,note"},"recent_note":null,"completed_sales_sequences":null,"active_sales_sequences":null,"web_form_id":null,"upcoming_activities_time":null,"collaboration":{},"last_assigned_at":null,"last_contacted_sales_activity_mode":null,"last_contacted_via_sales_activity":null,"expected_deal_value":"0.0","is_deleted":false,"team_user_ids":null,"avatar":null,"fc_widget_collaboration":{"convo_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJDb252b0lkIjoiMzEwMDY5MjEwOTEiLCJ0eXBlIjoiZGVhbCJ9.oUnqqnQzaZeYgBVpbytlqivgk29eKUMQKGKmjDRLalQ","auth_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJVc2VyVVVJRCI6IjU5NDI3NzY4MTIwMzkyMzY2NCJ9.tVm7b6vZJUzA5Bk1FaSWvkm5wcl_W3DhDAQE-NgdtSE","encoded_jwt_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..8X7CwUKd9hhNxnfYZEAgXe0zrhmB3SYg_zyQW81CGP8"},"forecast_category":null,"deal_prediction":0,"deal_prediction_last_updated_at":null,"freddy_forecast_metrics":null,"last_deal_prediction":null,"has_products":false,"products":[],"deal_price_adjustments":[],"rotten_days":null,"tags":[],"creater_id":31000890026}}
# Erreur création affaire pour le contact 31118732411: {"users":[{"id":31000890026,"display_name":"James Aurelie","email":"accueil@sarahnacass.com","is_active":true,"work_number":null,"mobile_number":null}],"deal":{"id":31006921092,"name":"Affaire générée automatiquement","amount":"0.0","base_currency_amount":"0.0","expected_close":null,"closed_date":null,"stage_updated_time":"2025-05-12T15:55:28+02:00","custom_field":{"cf_transaction":null,"cf_activit":null,"cf_statut_du_paiement":null,"cf_statut_de_livraison":null,"cf_types":null,"cf_sources":null,"cf_information_sur_la_source":null,"cf_chemin_du_client":null,"cf_url_de_la_source":null,"cf_score":null,"cf_objectif_formul":null,"cf_date_de_naissance":null,"cf_budget_journalier_utm_medium":null,"cf_action_initiale_du_prospect":null,"cf_etapes_de_la_transaction":null,"cf_date_de_creation":null,"cf_etapes_de_formation":null,"cf_id_bitrix":null,"cf_mobile":null,"cf_email":null,"cf_valeur_de_laffaire_2":null},"probability":50,"updated_at":"2025-05-12T15:55:28+02:00","created_at":"2025-05-12T15:55:28+02:00","deal_pipeline_id":31000077536,"deal_stage_id":31000543862,"age":0,"links":{"conversations":"/crm/sales/deals/31006921092/conversations/all?include=email_conversation_recipients%2Ctargetable%2Cphone_number%2Cphone_caller%2Cnote%2Cuser\u0026per_page=3","document_associations":"/crm/sales/deals/31006921092/document_associations","notes":"/crm/sales/deals/31006921092/notes?include=creater","tasks":"/crm/sales/deals/31006921092/tasks?include=creater,owner,updater,targetable,users,task_type","appointments":"/crm/sales/deals/31006921092/appointments?include=creater,owner,updater,targetable,appointment_attendees,conference,note"},"recent_note":null,"completed_sales_sequences":null,"active_sales_sequences":null,"web_form_id":null,"upcoming_activities_time":null,"collaboration":{},"last_assigned_at":null,"last_contacted_sales_activity_mode":null,"last_contacted_via_sales_activity":null,"expected_deal_value":"0.0","is_deleted":false,"team_user_ids":null,"avatar":null,"fc_widget_collaboration":{"convo_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJDb252b0lkIjoiMzEwMDY5MjEwOTIiLCJ0eXBlIjoiZGVhbCJ9.rK9DgwiRlIa_fIGJagzSx_sMLBvI97NOMVrTZF2DVDk","auth_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJVc2VyVVVJRCI6IjU5NDI3NzY4MTIwMzkyMzY2NCJ9.tVm7b6vZJUzA5Bk1FaSWvkm5wcl_W3DhDAQE-NgdtSE","encoded_jwt_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..Rn4tDDTul2ib0EmuxIbzm01_kf8Y4LShDHzrRR1MEGU"},"forecast_category":null,"deal_prediction":0,"deal_prediction_last_updated_at":null,"freddy_forecast_metrics":null,"last_deal_prediction":null,"has_products":false,"products":[],"deal_price_adjustments":[],"rotten_days":null,"tags":[],"creater_id":31000890026}}
# Affaire 31006231047 mise à jour vers 'MPA prévue'
# Affaire 31006050733 mise à jour vers 'MPA prévue'
# Affaire 31006313530 mise à jour vers 'MPA prévue'
# Erreur création affaire pour le contact 31121174532: {"users":[{"id":31000890026,"display_name":"James Aurelie","email":"accueil@sarahnacass.com","is_active":true,"work_number":null,"mobile_number":null}],"deal":{"id":31006921093,"name":"Affaire générée automatiquement","amount":"0.0","base_currency_amount":"0.0","expected_close":null,"closed_date":null,"stage_updated_time":"2025-05-12T15:55:35+02:00","custom_field":{"cf_transaction":null,"cf_activit":null,"cf_statut_du_paiement":null,"cf_statut_de_livraison":null,"cf_types":null,"cf_sources":null,"cf_information_sur_la_source":null,"cf_chemin_du_client":null,"cf_url_de_la_source":null,"cf_score":null,"cf_objectif_formul":null,"cf_date_de_naissance":null,"cf_budget_journalier_utm_medium":null,"cf_action_initiale_du_prospect":null,"cf_etapes_de_la_transaction":null,"cf_date_de_creation":null,"cf_etapes_de_formation":null,"cf_id_bitrix":null,"cf_mobile":null,"cf_email":null,"cf_valeur_de_laffaire_2":null},"probability":50,"updated_at":"2025-05-12T15:55:35+02:00","created_at":"2025-05-12T15:55:35+02:00","deal_pipeline_id":31000077536,"deal_stage_id":31000543862,"age":0,"links":{"conversations":"/crm/sales/deals/31006921093/conversations/all?include=email_conversation_recipients%2Ctargetable%2Cphone_number%2Cphone_caller%2Cnote%2Cuser\u0026per_page=3","document_associations":"/crm/sales/deals/31006921093/document_associations","notes":"/crm/sales/deals/31006921093/notes?include=creater","tasks":"/crm/sales/deals/31006921093/tasks?include=creater,owner,updater,targetable,users,task_type","appointments":"/crm/sales/deals/31006921093/appointments?include=creater,owner,updater,targetable,appointment_attendees,conference,note"},"recent_note":null,"completed_sales_sequences":null,"active_sales_sequences":null,"web_form_id":null,"upcoming_activities_time":null,"collaboration":{},"last_assigned_at":null,"last_contacted_sales_activity_mode":null,"last_contacted_via_sales_activity":null,"expected_deal_value":"0.0","is_deleted":false,"team_user_ids":null,"avatar":null,"fc_widget_collaboration":{"convo_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJDb252b0lkIjoiMzEwMDY5MjEwOTMiLCJ0eXBlIjoiZGVhbCJ9.vxMXQwIFDQv8lVRovQuYnYxDmVhB5Lm77w6GhgbyaR0","auth_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJVc2VyVVVJRCI6IjU5NDI3NzY4MTIwMzkyMzY2NCJ9.tVm7b6vZJUzA5Bk1FaSWvkm5wcl_W3DhDAQE-NgdtSE","encoded_jwt_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..YPQwZokk8NK2fno7kV_VfgdsrYltkiLspEl7pW4gtTM"},"forecast_category":null,"deal_prediction":0,"deal_prediction_last_updated_at":null,"freddy_forecast_metrics":null,"last_deal_prediction":null,"has_products":false,"products":[],"deal_price_adjustments":[],"rotten_days":null,"tags":[],"creater_id":31000890026}}
# Affaire 31006276366 mise à jour vers 'MPA prévue'

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;"> Suivi de l’évolution des programmes payée montant supérieur a 200€ -> en bonne voie</span>

# %%
import pandas as pd

df = pd.read_csv('azfsdtord.csv')

filtré = df[
    df['Name'].str.contains("programme", case=False, na=False) &
    df['Statut récent'].str.contains("payée", case=False, na=False)
]

filtré.to_csv("programmes.csv", index=False)


print(f"{len(filtré)} lignes filtrées avec 'programme' dans 'Type de RDV'")
filtré

# %%
import csv
import requests
import time

API_KEY_FRESHWORK = ''
DOMAIN_FRESHWORK = ''
BASE_URL = f'https://{DOMAIN_FRESHWORK}.myfreshworks.com/crm/sales/'

HEADERS = {
    'Content-Type': 'application/json',
    'Authorization': f'Token token={API_KEY_FRESHWORK}'
}

DEFAULT_DEAL_STAGE_ID = 31000584324

def get_existing_contacts():
    print("\nRécupération des contacts existants (email)...")
    all_contacts = {}
    page = 1
    while True:
        url = f"{BASE_URL}api/contacts/view/31004512042?sort=created_at&per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Erreur contacts: {response.text}")
            return {}
        contacts_data = response.json().get("contacts", [])
        if not contacts_data:
            break
        for contact in contacts_data:
            email = contact.get("email")
            if email:
                all_contacts[email.strip().lower()] = contact["id"]
        page += 1
        time.sleep(1)
    print(f"{len(all_contacts)} contacts récupérés.")
    return all_contacts

def get_existing_deal(contact_id):
    url = f"{BASE_URL}api/contacts/{contact_id}/deals"
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Erreur récupération des affaires pour contact {contact_id}")
        return None
    deals = response.json().get("deals", [])
    for deal in deals:
        try:
            amount = float(deal.get("amount", 0) or 0)
        except:
            amount = 0
        if amount > 0:
            return deal
    return None

def update_deal_stage(deal_id, new_stage_id=DEFAULT_DEAL_STAGE_ID):
    url = f"{BASE_URL}api/deals/{deal_id}"
    payload = {
        "deal": {
            "deal_stage_id": new_stage_id
        }
    }
    response = requests.put(url, headers=HEADERS, json=payload)
    if response.status_code == 200:
        print(f"Affaire {deal_id} mise à jour vers 'Programme'")
    else:
        print(f"Erreur mise à jour affaire {deal_id}: {response.text}")

def main():
    print("Pause 1/2 : 1 heure avant la récupération des contacts...")
    time.sleep(1)

    existing_contacts = get_existing_contacts()

    with open('programmes.csv', 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        bitrix_contacts = list(reader)

    print("Pause 2/2 : 1 heure avant la mise à jour des affaires...")
    time.sleep(1)

    for contact in bitrix_contacts:
        email = contact.get('Email', '').strip().lower()
        if not email:
            continue
        if email in existing_contacts:
            contact_id = existing_contacts[email]
            deal = get_existing_deal(contact_id)
            if deal:
                update_deal_stage(deal['id'])
        time.sleep(1)

if __name__ == "__main__":
    main()
# Out:
# Pause 1/2 : 1 heure avant la récupération des contacts...
#
# Récupération des contacts existants (email)...
# 38729 contacts récupérés.
# Pause 2/2 : 1 heure avant la mise à jour des affaires...
# Affaire 31005403555 mise à jour vers 'Programme'
# Affaire 31005206149 mise à jour vers 'Programme'
# Affaire 31005214867 mise à jour vers 'Programme'
# Affaire 31003841096 mise à jour vers 'Programme'
# Affaire 31005843403 mise à jour vers 'Programme'
# Affaire 31003030457 mise à jour vers 'Programme'
# Affaire 31003031920 mise à jour vers 'Programme'
# Affaire 31003031502 mise à jour vers 'Programme'
# Affaire 31003031173 mise à jour vers 'Programme'
# Affaire 31005928505 mise à jour vers 'Programme'
# Affaire 31003031391 mise à jour vers 'Programme'
# Affaire 31005756337 mise à jour vers 'Programme'
# Affaire 31003598247 mise à jour vers 'Programme'
# Affaire 31003031198 mise à jour vers 'Programme'
# Affaire 31005756220 mise à jour vers 'Programme'
# Affaire 31005211251 mise à jour vers 'Programme'
# Affaire 31005209257 mise à jour vers 'Programme'
# Affaire 31003030419 mise à jour vers 'Programme'
# Affaire 31005949462 mise à jour vers 'Programme'
# Affaire 31004008644 mise à jour vers 'Programme'
# Affaire 31005211011 mise à jour vers 'Programme'
# Affaire 31005739471 mise à jour vers 'Programme'
# Affaire 31004007830 mise à jour vers 'Programme'
# Affaire 31005949575 mise à jour vers 'Programme'
# Affaire 31003030363 mise à jour vers 'Programme'
# Affaire 31003030472 mise à jour vers 'Programme'
# Affaire 31005928435 mise à jour vers 'Programme'
# Affaire 31003030522 mise à jour vers 'Programme'
# Affaire 31005213930 mise à jour vers 'Programme'
# Affaire 31005209037 mise à jour vers 'Programme'
# Affaire 31005205757 mise à jour vers 'Programme'
# Affaire 31005211405 mise à jour vers 'Programme'
# Affaire 31005214392 mise à jour vers 'Programme'
# Affaire 31003032056 mise à jour vers 'Programme'
# Affaire 31003030441 mise à jour vers 'Programme'
# Affaire 31003031677 mise à jour vers 'Programme'
# Affaire 31004065774 mise à jour vers 'Programme'
# Affaire 31005928327 mise à jour vers 'Programme'
# Affaire 31003542265 mise à jour vers 'Programme'
# Affaire 31005214377 mise à jour vers 'Programme'
# Affaire 31005209116 mise à jour vers 'Programme'
